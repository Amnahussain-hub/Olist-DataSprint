# %%
import pandas as pd

# %%
olist_colsed=pd.read_csv('olist_closed_deals_dataset.csv')

# %%
olist_colsed.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#                              sdr_id                             sr_id  \
# 0  a8387c01a09e99ce014107505b92388c  4ef15afb4b2723d8f3d81e51ec7afefe
# 1  09285259593c61296eef10c734121d5b  d3d1e91a157ea7f90548eef82f1955e3
# 2  b90f87164b5f8c2cfa5c8572834dbe3f  6565aa9ce3178a5caf6171827af3a9ba
# 3  56bf83c4bb35763a51c2baab501b4c67  d3d1e91a157ea7f90548eef82f1955e3
# 4  4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
#
#               won_date business_segment      lead_type lead_behaviour_profile  \
# 0  2018-02-26 19:58:54              pet  online_medium                    cat
# 1  2018-05-08 20:17:59  car_accessories       industry                  eagle
# 2  2018-06-05 17:27:23  home_appliances     online_big                    cat
# 3  2018-01-17 13:51:03       food_drink   online_small                    NaN
# 4  2018-07-03 20:17:45  home_appliances       industry                   wolf
#
#   has_company has_gtin average_stock business_type  \
# 0         NaN      NaN           NaN      reseller
# 1         NaN      NaN           NaN      reseller
# 2         NaN      NaN           NaN      reseller
# 3         NaN      NaN           NaN      reseller
# 4         NaN      NaN           NaN  manufacturer
#
#    declared_product_catalog_size  declared_monthly_revenue
# 0                            NaN                       0.0
# 1                            NaN                       0.0
# 2                            NaN                       0.0
# 3                            NaN                       0.0
# 4                            NaN                       0.0

# %%
olist_colsed.isnull().mean()*100
# Out:
# mql_id                            0.000000
# seller_id                         0.000000
# sdr_id                            0.000000
# sr_id                             0.000000
# won_date                          0.000000
# business_segment                  0.000000
# lead_type                         0.000000
# lead_behaviour_profile           20.727273
# has_company                      92.363636
# has_gtin                         92.242424
# average_stock                    92.000000
# business_type                     0.000000
# declared_product_catalog_size    91.636364
# declared_monthly_revenue          0.000000
# dtype: float64

# %%
olist_colsed= olist_colsed.dropna(subset=[
    'business_segment', 
    'lead_type', 
    'business_type', 
])

# %%
olist_colsed.lead_type.unique()
# Out:
# array(['online_medium', 'industry', 'online_big', 'online_small',
#        'offline', 'online_top', 'online_beginner', 'other'], dtype=object)

# %%
olist_colsed.lead_type.value_counts()
# Out:
# lead_type
# online_medium      327
# online_big         126
# industry           119
# offline            102
# online_small        77
# online_beginner     57
# online_top          14
# other                3
# Name: count, dtype: int64

# %%
olist_colsed.business_type.unique()
# Out:
# array(['reseller', 'manufacturer', 'other'], dtype=object)

# %%
olist_colsed.seller_id.nunique()
# Out:
# 825

# %%
olist_colsed.groupby('business_type')['seller_id'].nunique()
# Out:
# business_type
# manufacturer    242
# other             3
# reseller        580
# Name: seller_id, dtype: int64

# %%
olist_colsed.business_type.value_counts()
# Out:
# business_type
# reseller        580
# manufacturer    242
# other             3
# Name: count, dtype: int64

# %%
olist_colsed.declared_monthly_revenue.value_counts()
# Out:
# declared_monthly_revenue
# 0.0           780
# 100000.0        5
# 20000.0         3
# 30000.0         3
# 10000.0         3
# 25000.0         3
# 50000.0         2
# 5000.0          2
# 300000.0        2
# 250000.0        2
# 15000.0         2
# 60000.0         2
# 120000.0        2
# 50000000.0      1
# 6.0             1
# 6000.0          1
# 150000.0        1
# 180000.0        1
# 8000000.0       1
# 4000.0          1
# 40000.0         1
# 210000.0        1
# 1000.0          1
# 500000.0        1
# 130000.0        1
# 8000.0          1
# 200000.0        1
# Name: count, dtype: int64

# %%
#create dataframe only for manufacture:
olist_colsed_manufacture = olist_colsed[olist_colsed['business_type'] == 'manufacturer']

# %%
olist_colsed_manufacture
# Out:
#                                mql_id                         seller_id  \
# 4    ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
# 5    b94fba7670eeb44dce2a0d8eb790e9f5  1c742ac33582852aaf3bcfbf5893abcf
# 7    b02c89251106e1fdd9d92744be9f94f2  44ed138eca6214d572ce1d813fb0049b
# 9    0173e8d8b1d94a355b440fb67388f532  87d73636a3acf123e842bb890a4db036
# 16   450b97a48568c3118ff397f73abe4e4a  df91910b6a03bb2e3358fa6a35e32f6f
# ..                                ...                               ...
# 788  100a1f43c56bb71781a2231a79900488  297be0a3c196d803e4e4f013432be4e1
# 797  3223fed48f30bbdc0f6040b466516bcb  0d7d5bca59d45d750fb7913b974e9d08
# 812  72477e4cbc223fd605cdf76361cbe0a6  a9f81449e8f8a47f6c67e5a43b40ed04
# 819  e7f70a2ff45e44c7399bebacf3e4771d  b21768cfefb49b94e9bcd38037e93d1f
# 824  8a6492305a5fbcdcdd1a7f5a90764c07  1bba9c94eb5c4e82fba9f7286fe81025
#
#                                sdr_id                             sr_id  \
# 4    4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
# 5    fdb16d3cbbeb5798f2f66c4096be026d  495d4e95a8cf8bbf8b432b612a2aa328
# 7    34d40cdaf94010a1d05b0d6212f9e909  4ef15afb4b2723d8f3d81e51ec7afefe
# 9    9d12ef1a7eca3ec58c545c678af7869c  9e4d1098a3b0f5da39b0bc48f9876645
# 16   09285259593c61296eef10c734121d5b  060c0a26f19f4d66b42e0d8796688490
# ..                                ...                               ...
# 788  370c9f455f93a9a96cbe9bea48e70033  56bf83c4bb35763a51c2baab501b4c67
# 797  068066e24f0c643eb1d089c7dd20cd73  9749123c950bf8363ace42cb1c2d0815
# 812  068066e24f0c643eb1d089c7dd20cd73  060c0a26f19f4d66b42e0d8796688490
# 819  56bf83c4bb35763a51c2baab501b4c67  c638112b43f1d1b86dcabb0da720c901
# 824  56bf83c4bb35763a51c2baab501b4c67  de63de0d10a6012430098db33c679b0b
#
#                 won_date                 business_segment        lead_type  \
# 4    2018-07-03 20:17:45                  home_appliances         industry
# 5    2018-02-07 18:04:05                    health_beauty    online_medium
# 7    2018-04-17 17:01:57                    health_beauty          offline
# 9    2018-04-24 03:00:00              household_utilities    online_medium
# 16   2018-04-10 19:21:54                       food_drink    online_medium
# ..                   ...                              ...              ...
# 788  2018-07-30 14:02:01                       home_decor  online_beginner
# 797  2018-10-30 11:54:22  construction_tools_house_garden       online_big
# 812  2018-03-01 21:03:12                       food_drink         industry
# 819  2018-02-09 12:16:16                  car_accessories    online_medium
# 824  2018-05-02 13:31:32              household_utilities         industry
#
#     lead_behaviour_profile has_company has_gtin average_stock business_type  \
# 4                     wolf         NaN      NaN           NaN  manufacturer
# 5                      NaN         NaN      NaN           NaN  manufacturer
# 7                      cat         NaN      NaN           NaN  manufacturer
# 9                    eagle         NaN      NaN           NaN  manufacturer
# 16                     cat         NaN      NaN           NaN  manufacturer
# ..                     ...         ...      ...           ...           ...
# 788                  eagle         NaN      NaN           NaN  manufacturer
# 797                  shark        True     True           NaN  manufacturer
# 812                  eagle         NaN      NaN           NaN  manufacturer
# 819                    NaN         NaN      NaN           NaN  manufacturer
# 824                  eagle         NaN      NaN           NaN  manufacturer
#
#      declared_product_catalog_size  declared_monthly_revenue
# 4                              NaN                       0.0
# 5                              NaN                       0.0
# 7                              NaN                       0.0
# 9                              NaN                       0.0
# 16                             NaN                       0.0
# ..                             ...                       ...
# 788                            NaN                       0.0
# 797                           10.0                  250000.0
# 812                            NaN                       0.0
# 819                            NaN                       0.0
# 824                            NaN                       0.0
#
# [242 rows x 14 columns]

# %%
olist_colsed.won_date.unique()
# Out:
# array(['2018-02-26 19:58:54', '2018-05-08 20:17:59',
#        '2018-06-05 17:27:23', '2018-01-17 13:51:03',
#        '2018-07-03 20:17:45', '2018-02-07 18:04:05',
#        '2018-04-16 18:18:22', '2018-04-17 17:01:57',
#        '2018-05-14 18:37:15', '2018-04-24 03:00:00',
#        '2018-02-28 19:42:14', '2018-02-23 13:54:40',
#        '2018-05-22 13:24:08', '2018-06-14 14:30:20',
#        '2018-04-10 03:00:00', '2018-09-10 14:18:01',
#        '2018-04-10 19:21:54', '2018-01-26 17:23:46',
#        '2018-05-11 19:03:19', '2018-06-19 14:08:22',
#        '2018-02-07 13:57:02', '2018-04-16 13:09:09',
#        '2018-02-08 17:20:14', '2018-02-16 12:31:56',
#        '2018-02-22 12:40:15', '2018-02-12 13:18:13',
#        '2018-02-08 20:57:44', '2018-04-06 20:52:54',
#        '2018-04-13 12:27:48', '2018-04-18 18:02:08',
#        '2018-07-19 18:06:07', '2018-07-04 15:07:27',
#        '2018-04-25 03:00:00', '2018-06-05 17:20:34',
#        '2018-10-31 16:54:59', '2018-05-30 14:43:50',
#        '2018-03-06 12:25:29', '2018-09-27 12:31:01',
#        '2018-02-06 15:46:14', '2018-05-15 18:05:25',
#        '2018-06-11 12:40:42', '2018-11-14 18:04:19',
#        '2018-04-27 14:01:33', '2018-03-27 19:14:00',
#        '2018-06-18 13:58:00', '2018-04-11 03:00:00',
#        '2018-04-18 16:50:40', '2018-03-29 17:48:42',
#        '2018-02-22 13:18:26', '2018-02-27 20:04:12',
#        '2018-06-11 12:04:11', '2018-07-30 14:34:51',
#        '2018-04-02 14:20:33', '2018-04-13 12:50:35',
#        '2018-03-23 19:06:54', '2018-04-26 03:00:00',
#        '2018-03-12 13:21:11', '2018-04-30 21:13:36',
#        '2018-04-27 13:35:00', '2018-09-04 14:15:04',
#        '2018-05-18 18:08:22', '2018-02-27 19:19:47',
#        '2018-01-12 16:07:27', '2018-02-26 12:45:46',
#        '2018-04-03 03:00:00', '2018-04-27 16:11:57',
#        '2018-04-27 20:44:40', '2018-02-22 21:07:50',
#        '2018-05-25 17:32:40', '2018-04-27 12:18:34',
#        '2018-07-19 21:17:47', '2018-04-24 20:54:30',
#        '2018-02-06 20:18:28', '2018-03-23 21:07:18',
#        '2018-01-19 13:12:10', '2018-01-26 16:27:17',
#        '2018-01-08 02:00:00', '2018-04-26 19:36:13',
#        '2018-05-22 12:54:36', '2018-06-04 00:00:00',
#        '2018-02-20 12:17:26', '2018-03-13 20:12:45',
#        '2018-05-18 20:02:04', '2018-07-30 14:02:01',
#        '2018-06-29 17:54:16', '2018-05-18 12:38:36',
#        '2018-01-24 12:27:42', '2018-02-19 19:51:00',
#        '2018-05-29 18:53:31', '2018-11-12 19:17:25',
#        '2018-09-10 20:48:01', '2018-04-05 16:29:23',
#        '2018-10-30 11:54:22', '2018-04-06 16:52:50',
#        '2018-04-17 17:18:09', '2018-05-30 03:00:00',
#        '2018-02-15 11:27:17', '2018-02-21 13:27:48',
#        '2018-02-05 12:51:36', '2018-03-26 14:03:55',
#        '2018-07-17 20:12:39', '2018-04-06 19:30:00',
#        '2018-02-01 17:10:20', '2018-04-06 19:26:13',
#        '2018-05-16 19:51:05', '2018-04-06 20:40:05',
#        '2018-03-01 21:03:12', '2017-12-05 02:00:00',
#        '2018-03-29 19:37:01', '2018-04-04 20:33:19',
#        '2018-03-28 22:42:55', '2018-04-20 12:27:44',
#        '2018-06-07 21:23:45', '2018-02-09 12:16:16',
#        '2018-08-01 20:22:31', '2018-09-27 18:58:41',
#        '2018-06-06 20:15:26', '2018-03-06 15:52:23',
#        '2018-05-02 13:31:32'], dtype=object)

# %%
olist_customers=pd.read_csv('olist_customers_dataset.csv')

# %%
olist_customers.isnull().mean()*100
# Out:
# customer_id                 0.0
# customer_unique_id          0.0
# customer_zip_code_prefix    0.0
# customer_city               0.0
# customer_state              0.0
# dtype: float64

# %%
olist_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
olist_seller=pd.read_csv('olist_sellers_dataset.csv')

# %%
olist_seller.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
olist_seller['seller_id'].nunique()
# Out:
# 3095

# %%
olist_seller.isnull().mean()*100
# Out:
# seller_id                 0.0
# seller_zip_code_prefix    0.0
# seller_city               0.0
# seller_state              0.0
# dtype: float64

# %%
olist_orders_item=pd.read_csv('olist_order_items_dataset.csv')

# %%
olist_orders_item.isnull().mean()*100
# Out:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64

# %%
olist_orders_item
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 7 columns]

# %%
olist_orders_item.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
#convert shipping limit date to date

# %%
olist_review=pd.read_csv('olist_order_reviews_dataset.csv')

# %%
olist_review.isnull().mean()*100
# Out:
# review_id                   0.000000
# order_id                    0.000000
# review_score                0.000000
# review_comment_title       88.341530
# review_comment_message     58.702532
# review_creation_date        0.000000
# review_answer_timestamp     0.000000
# dtype: float64

# %%
olist_review.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
olist_golocation=pd.read_csv('olist_geolocation_dataset.csv')

# %%
olist_golocation.isnull().mean()*100
# Out:
# geolocation_zip_code_prefix    0.0
# geolocation_lat                0.0
# geolocation_lng                0.0
# geolocation_city               0.0
# geolocation_state              0.0
# dtype: float64

# %%
olist_golocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
olist_payment=pd.read_csv('olist_order_payments_dataset.csv')

# %%
olist_payment.isnull().mean()*100
# Out:
# order_id                0.0
# payment_sequential      0.0
# payment_type            0.0
# payment_installments    0.0
# payment_value           0.0
# dtype: float64

# %%
olist_payment.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
olist_payment.payment_type.value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
olist_payment= olist_payment.drop(olist_payment[olist_payment['payment_type'] == 'not_defined'].index)
olist_payment.payment_type.value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# Name: count, dtype: int64

# %%
product_category=pd.read_csv('product_category_name_translation.csv')

# %%
product_category.isnull().mean()*100
# Out:
# product_category_name            0.0
# product_category_name_english    0.0
# dtype: float64

# %%
product_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_category.product_category_name_english.unique()
# Out:
# array(['health_beauty', 'computers_accessories', 'auto', 'bed_bath_table',
#        'furniture_decor', 'sports_leisure', 'perfumery', 'housewares',
#        'telephony', 'watches_gifts', 'food_drink', 'baby', 'stationery',
#        'tablets_printing_image', 'toys', 'fixed_telephony',
#        'garden_tools', 'fashion_bags_accessories', 'small_appliances',
#        'consoles_games', 'audio', 'fashion_shoes', 'cool_stuff',
#        'luggage_accessories', 'air_conditioning',
#        'construction_tools_construction',
#        'kitchen_dining_laundry_garden_furniture',
#        'costruction_tools_garden', 'fashion_male_clothing', 'pet_shop',
#        'office_furniture', 'market_place', 'electronics',
#        'home_appliances', 'party_supplies', 'home_confort',
#        'costruction_tools_tools', 'agro_industry_and_commerce',
#        'furniture_mattress_and_upholstery', 'books_technical',
#        'home_construction', 'musical_instruments',
#        'furniture_living_room', 'construction_tools_lights',
#        'industry_commerce_and_business', 'food', 'art',
#        'furniture_bedroom', 'books_general_interest',
#        'construction_tools_safety', 'fashion_underwear_beach',
#        'fashion_sport', 'signaling_and_security', 'computers',
#        'christmas_supplies', 'fashio_female_clothing',
#        'home_appliances_2', 'books_imported', 'drinks', 'cine_photo',
#        'la_cuisine', 'music', 'home_comfort_2',
#        'small_appliances_home_oven_and_coffee', 'cds_dvds_musicals',
#        'dvds_blu_ray', 'flowers', 'arts_and_craftmanship',
#        'diapers_and_hygiene', 'fashion_childrens_clothes',
#        'security_and_services'], dtype=object)

# %%
orders=pd.read_csv('olist_orders_dataset.csv')

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders.isnull().mean()*100
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.160899
# order_delivered_carrier_date     1.793023
# order_delivered_customer_date    2.981668
# order_estimated_delivery_date    0.000000
# dtype: float64

# %%
orders =orders.dropna(subset=[
    'order_approved_at', 
    'order_delivered_carrier_date', 
    'order_delivered_customer_date', 
])

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
orders['order_delivered_carrier_date']=pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date']=pd.to_datetime(orders['order_delivered_customer_date'])
orders['oorder_estimated_delivery_date']=pd.to_datetime(orders['order_estimated_delivery_date'])

# %%
#orders['order_purchase_date'] = orders['order_purchase_timestamp'].dt.date

# %%
olist_products=pd.read_csv('olist_products_dataset.csv')

# %%
columns_prodcuts = [
    'product_category_name', 
    'product_name_lenght', 
    'product_description_lenght', 
    'product_photos_qty'
]

# %%
olist_products = olist_products.dropna(subset=[
    'product_category_name', 
    'product_name_lenght', 
    'product_description_lenght', 
    'product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm' 
])

# %%
olist_products.isnull().mean()*100
# Out:
# product_id                    0.0
# product_category_name         0.0
# product_name_lenght           0.0
# product_description_lenght    0.0
# product_photos_qty            0.0
# product_weight_g              0.0
# product_length_cm             0.0
# product_height_cm             0.0
# product_width_cm              0.0
# dtype: float64

# %%
olist_products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
olist_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
olist_products.product_category_name.unique()
# Out:
# array(['perfumaria', 'artes', 'esporte_lazer', 'bebes',
#        'utilidades_domesticas', 'instrumentos_musicais', 'cool_stuff',
#        'moveis_decoracao', 'eletrodomesticos', 'brinquedos',
#        'cama_mesa_banho', 'construcao_ferramentas_seguranca',
#        'informatica_acessorios', 'beleza_saude', 'malas_acessorios',
#        'ferramentas_jardim', 'moveis_escritorio', 'automotivo',
#        'eletronicos', 'fashion_calcados', 'telefonia', 'papelaria',
#        'fashion_bolsas_e_acessorios', 'pcs', 'casa_construcao',
#        'relogios_presentes', 'construcao_ferramentas_construcao',
#        'pet_shop', 'eletroportateis', 'agro_industria_e_comercio',
#        'moveis_sala', 'sinalizacao_e_seguranca', 'climatizacao',
#        'consoles_games', 'livros_interesse_geral',
#        'construcao_ferramentas_ferramentas',
#        'fashion_underwear_e_moda_praia', 'fashion_roupa_masculina',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
#        'industria_comercio_e_negocios', 'telefonia_fixa',
#        'construcao_ferramentas_iluminacao', 'livros_tecnicos',
#        'eletrodomesticos_2', 'artigos_de_festas', 'bebidas',
#        'market_place', 'la_cuisine', 'construcao_ferramentas_jardim',
#        'fashion_roupa_feminina', 'casa_conforto', 'audio',
#        'alimentos_bebidas', 'musica', 'alimentos',
#        'tablets_impressao_imagem', 'livros_importados',
#        'portateis_casa_forno_e_cafe', 'fashion_esporte',
#        'artigos_de_natal', 'fashion_roupa_infanto_juvenil',
#        'dvds_blu_ray', 'artes_e_artesanato', 'pc_gamer', 'moveis_quarto',
#        'cine_foto', 'fraldas_higiene', 'flores', 'casa_conforto_2',
#        'portateis_cozinha_e_preparadores_de_alimentos',
#        'seguros_e_servicos', 'moveis_colchao_e_estofado',
#        'cds_dvds_musicais'], dtype=object)

# %%
olist_marketing=pd.read_csv('olist_marketing_qualified_leads_dataset.csv')

# %%
olist_marketing.isnull().mean()*100
# Out:
# mql_id                0.00
# first_contact_date    0.00
# landing_page_id       0.00
# origin                0.75
# dtype: float64

# %%
olist_marketing.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
orders.to_csv('clean_olist_orders.csv', index=False)
olist_orders_item.to_csv('clean_olist_order_items.csv', index=False)
olist_review.to_csv('clean_olist_order_reviews.csv', index=False)
olist_payment.to_csv('clean_olist_order_payments.csv', index=False)
olist_customers.to_csv('clean_olist_customers.csv', index=False)
olist_products.to_csv('clean_olist_products.csv', index=False)
olist_seller.to_csv('clean_olist_sellers.csv', index=False)
olist_golocation.to_csv('clean_olist_geolocation.csv', index=False)
olist_marketing.to_csv('clean_olist_marketing_qualified_leads_dataset.csv',index=False)
olist_colsed.to_csv('olist_closed_deals_dataset.csv',index=False)

# %%
olist_colsed.to_csv('clean_olist_closed_deals_dataset.csv',index=False)
product_category.to_csv('clean_product_category_name_translation.csv',index=False)

# %%
product_category.product_category_name_english.unique()
# Out:
# array(['health_beauty', 'computers_accessories', 'auto', 'bed_bath_table',
#        'furniture_decor', 'sports_leisure', 'perfumery', 'housewares',
#        'telephony', 'watches_gifts', 'food_drink', 'baby', 'stationery',
#        'tablets_printing_image', 'toys', 'fixed_telephony',
#        'garden_tools', 'fashion_bags_accessories', 'small_appliances',
#        'consoles_games', 'audio', 'fashion_shoes', 'cool_stuff',
#        'luggage_accessories', 'air_conditioning',
#        'construction_tools_construction',
#        'kitchen_dining_laundry_garden_furniture',
#        'costruction_tools_garden', 'fashion_male_clothing', 'pet_shop',
#        'office_furniture', 'market_place', 'electronics',
#        'home_appliances', 'party_supplies', 'home_confort',
#        'costruction_tools_tools', 'agro_industry_and_commerce',
#        'furniture_mattress_and_upholstery', 'books_technical',
#        'home_construction', 'musical_instruments',
#        'furniture_living_room', 'construction_tools_lights',
#        'industry_commerce_and_business', 'food', 'art',
#        'furniture_bedroom', 'books_general_interest',
#        'construction_tools_safety', 'fashion_underwear_beach',
#        'fashion_sport', 'signaling_and_security', 'computers',
#        'christmas_supplies', 'fashio_female_clothing',
#        'home_appliances_2', 'books_imported', 'drinks', 'cine_photo',
#        'la_cuisine', 'music', 'home_comfort_2',
#        'small_appliances_home_oven_and_coffee', 'cds_dvds_musicals',
#        'dvds_blu_ray', 'flowers', 'arts_and_craftmanship',
#        'diapers_and_hygiene', 'fashion_childrens_clothes',
#        'security_and_services'], dtype=object)

# %%
olist_colsed.business_segment.unique()
# Out:
# array(['pet', 'car_accessories', 'home_appliances', 'food_drink',
#        'health_beauty', 'computers', 'household_utilities',
#        'construction_tools_house_garden', 'toys', 'sports_leisure',
#        'stationery', 'food_supplement', 'home_decor', 'bed_bath_table',
#        'watches', 'fashion_accessories', 'jewerly', 'party',
#        'small_appliances', 'audio_video_electronics', 'other',
#        'bags_backpacks', 'home_office_furniture', 'music_instruments',
#        'books', 'baby', 'air_conditioning', 'phone_mobile', 'handcrafted',
#        'perfume', 'gifts', 'religious', 'games_consoles'], dtype=object)
